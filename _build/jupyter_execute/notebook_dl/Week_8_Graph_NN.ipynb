# %% [markdown]
# # Graph Neural Networks

# %% [markdown]
# In this chapter, our learning objectives are to:
#
# 1.  Define a graph neural network
# 2.  Understand the steps and best practices to design and train a graph neural networks
# 3.  Distinguish GNN and other neural network methods
# 4.  Discuss the main applications of graph neural networks
